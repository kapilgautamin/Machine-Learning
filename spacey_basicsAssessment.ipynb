# %% [markdown]
# <a href="https://colab.research.google.com/github/kapilgautamin/Machine-Learning-/blob/master/spacey_basicsAssessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NLP Basics Assessment

# %% [markdown]
# For this assessment we'll be using the short story [_An Occurrence at Owl Creek Bridge_](https://en.wikipedia.org/wiki/An_Occurrence_at_Owl_Creek_Bridge) by Ambrose Bierce (1890). <br>The story is in the public domain; the text file was obtained from [Project Gutenberg](https://www.gutenberg.org/ebooks/375.txt.utf-8).

# %%
# RUN THIS CELL to perform standard imports:
import spacy
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# **1. Create a Doc object from the file `owlcreek.txt`**<br>
# > HINT: Use `with open('../TextFiles/owlcreek.txt') as f:`

# %%
# Enter your code here:
with open("owlcreek.txt") as f:
  text = f.read()
doc = nlp(text)

# %%
# Run this cell to verify it worked:
doc[:36]
# Out:
# AN OCCURRENCE AT OWL CREEK BRIDGE
#
# by Ambrose Bierce
#
# I
#
# A man stood upon a railroad bridge in northern Alabama, looking down
# into the swift water twenty feet below.

# %% [markdown]
# **2. How many tokens are contained in the file?**

# %%
len(doc)
# Out:
# 4833

# %% [markdown]
# **3. How many sentences are contained in the file?**<br>HINT: You'll want to build a list first!

# %%
#Sentences can span lines, so the '\n' won't work
sents = text.split('\n')
len(sents)
# Out:
# 376

# %%
sents = list(doc.sents)
len(sents)
# Out:
# 222

# %% [markdown]
# **4. Print the second sentence in the document**<br> HINT: Indexing starts at zero, and the title counts as the first sentence.

# %%
sents[2]
# Out:
# A man stood upon a railroad bridge in northern Alabama, looking down
# into the swift water twenty feet below.

# %% [markdown]
# ** 5. For each token in the sentence above, print its `text`, `POS` tag, `dep` tag and `lemma`<br>
# CHALLENGE: Have values line up in columns in the print output.**

# %%
# NORMAL SOLUTION:
for token in doc:
  if token.text not in [',',' ','.',';','!','\n','\t','\"','--']:
    print(f'{token.text:{20}} {spacy.explain(token.pos_):{25}} {token.dep_:{20}} {token.lemma_:{20}}')
# Out:
# AN                   determiner                det                  an
# OCCURRENCE           noun                      compound             OCCURRENCE
# AT                   adposition                compound             at
# OWL                  proper noun               compound             OWL
# CREEK                proper noun               nsubj                CREEK
# BRIDGE               verb                      ROOT                 BRIDGE
#
#
#                    space
#
#
# by                   adposition                prep                 by
# Ambrose              proper noun               compound             Ambrose
# Bierce               proper noun               pobj                 Bierce
#
#
#                    space
#
#
# I                    pronoun                   ROOT                 -PRON-
#
#
#                    space
#
#
# A                    determiner                det                  a
# man                  noun                      nsubj                man
# stood                verb                      ROOT                 stand
# upon                 adposition                prep                 upon
# a                    determiner                det                  a
# railroad             noun                      compound             railroad
# bridge               noun                      pobj                 bridge
# in                   adposition                prep                 in
# northern             adjective                 amod                 northern
# Alabama              proper noun               pobj                 Alabama
# looking              verb                      advcl                look
# down                 adverb                    advmod               down
# into                 adposition                prep                 into
# the                  determiner                det                  the
# swift                adjective                 amod                 swift
# water                noun                      pobj                 water
# twenty               numeral                   nummod               twenty
# feet                 noun                      npadvmod             foot
# below                adverb                    advmod               below
# The                  determiner                det                  the
# man                  noun                      poss                 man
# 's                   particle                  case                 's
# hands                noun                      nsubj                hand
# were                 verb                      ccomp                be
# behind               adposition                prep                 behind
# his                  determiner                poss                 -PRON-
# back                 noun                      advmod               back
# the                  determiner                det                  the
# wrists               noun                      nsubj                wrist
# bound                verb                      ROOT                 bind
# with                 adposition                prep                 with
# a                    determiner                det                  a
# cord                 noun                      pobj                 cord
# A                    determiner                det                  a
# rope                 noun                      nsubj                rope
# closely              adverb                    advmod               closely
# encircled            verb                      ROOT                 encircle
# his                  determiner                poss                 -PRON-
# neck                 noun                      dobj                 neck
# It                   pronoun                   nsubjpass            -PRON-
# was                  verb                      auxpass              be
# attached             verb                      ROOT                 attach
# to                   adposition                prep                 to
# a                    determiner                det                  a
# stout                adjective                 amod                 stout
# cross                adjective                 subtok               cross
# -                    noun                      subtok               -
# timber               noun                      npadvmod             timber
# above                adposition                prep                 above
# his                  determiner                poss                 -PRON-
# head                 noun                      pobj                 head
# and                  coordinating conjunction  cc                   and
# the                  determiner                det                  the
# slack                noun                      nsubj                slack
# fell                 verb                      conj                 fall
# to                   adposition                prep                 to
# the                  determiner                det                  the
# level                noun                      pobj                 level
# of                   adposition                prep                 of
# his                  determiner                poss                 -PRON-
# knees                noun                      pobj                 knee
# Some                 determiner                det                  some
# loose                adjective                 amod                 loose
# boards               noun                      nsubj                board
# laid                 verb                      acl                  lay
# upon                 adposition                prep                 upon
# the                  determiner                det                  the
# ties                 noun                      pobj                 tie
# supporting           verb                      acl                  support
# the                  determiner                det                  the
# rails                noun                      dobj                 rail
# of                   adposition                prep                 of
# the                  determiner                det                  the
# railway              noun                      pobj                 railway
# supplied             verb                      ROOT                 supply
# a                    determiner                det                  a
# footing              noun                      dobj                 footing
# for                  adposition                prep                 for
# him                  pronoun                   pobj                 -PRON-
# and                  coordinating conjunction  cc                   and
# his                  determiner                poss                 -PRON-
# executioners         noun                      conj                 executioner
# two                  numeral                   nummod               two
# private              adjective                 amod                 private
# soldiers             noun                      appos                soldier
# of                   adposition                prep                 of
# the                  determiner                det                  the
# Federal              proper noun               compound             Federal
# army                 noun                      pobj                 army
# directed             verb                      advcl                direct
# by                   adposition                agent                by
# a                    determiner                det                  a
# sergeant             noun                      pobj                 sergeant
# who                  pronoun                   nsubj                who
# in                   adposition                prep                 in
# civil                adjective                 amod                 civil
# life                 noun                      pobj                 life
# may                  verb                      aux                  may
# have                 verb                      aux                  have
# been                 verb                      relcl                be
# a                    determiner                det                  a
# deputy               noun                      amod                 deputy
# sheriff              noun                      attr                 sheriff
# At                   adposition                prep                 at
# a                    determiner                det                  a
# short                adjective                 amod                 short
# remove               noun                      pobj                 remove
# upon                 adposition                prep                 upon
# the                  determiner                det                  the
# same                 adjective                 amod                 same
# temporary            adjective                 amod                 temporary
# platform             noun                      pobj                 platform
# was                  verb                      ROOT                 be
# an                   determiner                det                  an
# officer              noun                      attr                 officer
# in                   adposition                prep                 in
# the                  determiner                det                  the
# uniform              noun                      pobj                 uniform
# of                   adposition                prep                 of
# his                  determiner                poss                 -PRON-
# rank                 noun                      pobj                 rank
# armed                adjective                 acl                  armed
# He                   pronoun                   nsubj                -PRON-
# was                  verb                      ROOT                 be
# a                    determiner                det                  a
# captain              noun                      attr                 captain
# A                    determiner                det                  a
# sentinel             noun                      nsubj                sentinel
# at                   adposition                prep                 at
# each                 determiner                det                  each
# end                  noun                      pobj                 end
# of                   adposition                prep                 of
# the                  determiner                det                  the
# bridge               noun                      pobj                 bridge
# stood                verb                      ROOT                 stand
# with                 adposition                prep                 with
# his                  determiner                poss                 -PRON-
# rifle                noun                      pobj                 rifle
# in                   adposition                prep                 in
# the                  determiner                det                  the
# position             noun                      pobj                 position
# known                verb                      acl                  know
# as                   adposition                prep                 as
# support              noun                      pobj                 support
# that                 determiner                nsubj                that
# is                   verb                      parataxis            be
# to                   particle                  aux                  to
# say                  verb                      xcomp                say
# vertical             adjective                 advcl                vertical
# in                   adposition                prep                 in
# front                noun                      pobj                 front
# of                   adposition                prep                 of
# the                  determiner                det                  the
# left                 adjective                 amod                 left
# shoulder             noun                      pobj                 shoulder
# the                  determiner                det                  the
# hammer               noun                      nsubj                hammer
# resting              verb                      nsubj                rest
# on                   adposition                prep                 on
# the                  determiner                det                  the
# forearm              noun                      pobj                 forearm
# thrown               verb                      advcl                throw
# straight             adverb                    advmod               straight
# across               adposition                prep                 across
# the                  determiner                det                  the
# chest                noun                      pobj                 chest
# a                    determiner                det                  a
# formal               adjective                 amod                 formal
# and                  coordinating conjunction  cc                   and
# unnatural            adjective                 conj                 unnatural
# position             noun                      appos                position
# enforcing            verb                      advcl                enforce
# an                   determiner                det                  an
# erect                noun                      amod                 erect
# carriage             noun                      dobj                 carriage
# of                   adposition                prep                 of
# the                  determiner                det                  the
# body                 noun                      pobj                 body
# It                   pronoun                   nsubj                -PRON-
# did                  verb                      aux                  do
# not                  adverb                    neg                  not
# appear               verb                      ccomp                appear
# to                   particle                  aux                  to
# be                   verb                      xcomp                be
# the                  determiner                det                  the
# duty                 noun                      attr                 duty
# of                   adposition                prep                 of
# these                determiner                det                  these
# two                  numeral                   nummod               two
# men                  noun                      pobj                 man
# to                   particle                  aux                  to
# know                 verb                      advcl                know
# what                 pronoun                   nsubj                what
# was                  verb                      aux                  be
# occurring            verb                      ccomp                occur
# at                   adposition                prep                 at
# the                  determiner                det                  the
# center               noun                      pobj                 center
# of                   adposition                prep                 of
# the                  determiner                det                  the
# bridge               noun                      pobj                 bridge
# they                 pronoun                   nsubj                -PRON-
# merely               adverb                    advmod               merely
# blockaded            verb                      ROOT                 blockade
# the                  determiner                det                  the
# two                  numeral                   nummod               two
# ends                 noun                      dobj                 end
# of                   adposition                prep                 of
# the                  determiner                det                  the
# foot                 noun                      compound             foot
# planking             noun                      pobj                 planking
# that                 determiner                nsubj                that
# traversed            verb                      relcl                traverse
# it                   pronoun                   dobj                 -PRON-
#
#
#                    space
#
#
# Beyond               adposition                prep                 beyond
# one                  numeral                   pobj                 one
# of                   adposition                prep                 of
# the                  determiner                det                  the
# sentinels            noun                      pobj                 sentinel
# nobody               noun                      nsubj                nobody
# was                  verb                      relcl                be
# in                   adposition                prep                 in
# sight                noun                      pobj                 sight
# the                  determiner                det                  the
# railroad             noun                      nsubj                railroad
# ran                  verb                      ROOT                 run
# straight             adverb                    advmod               straight
# away                 adverb                    advmod               away
# into                 adposition                prep                 into
# a                    determiner                det                  a
# forest               noun                      pobj                 forest
# for                  adposition                prep                 for
# a                    determiner                quantmod             a
# hundred              numeral                   nummod               hundred
# yards                noun                      pobj                 yard
# then                 adverb                    advmod               then
# curving              verb                      advcl                curve
# was                  verb                      auxpass              be
# lost                 verb                      conj                 lose
# to                   particle                  aux                  to
# view                 verb                      xcomp                view
# Doubtless            proper noun               npadvmod             Doubtless
# there                adverb                    expl                 there
# was                  verb                      ROOT                 be
# an                   determiner                det                  an
# outpost              noun                      attr                 outpost
# farther              adverb                    advmod               farther
# along                adverb                    advmod               along
# The                  determiner                det                  the
# other                adjective                 amod                 other
# bank                 noun                      nsubj                bank
# of                   adposition                prep                 of
# the                  determiner                det                  the
# stream               noun                      pobj                 stream
# was                  verb                      ROOT                 be
# open                 adjective                 amod                 open
# ground               noun                      attr                 ground
# a                    determiner                det                  a
# gentle               adjective                 amod                 gentle
# slope                noun                      appos                slope
# topped               verb                      acl                  top
# with                 adposition                prep                 with
# a                    determiner                det                  a
# stockade             noun                      dobj                 stockade
# of                   adposition                prep                 of
# vertical             adjective                 amod                 vertical
# tree                 noun                      compound             tree
# trunks               noun                      pobj                 trunk
# loopholed            verb                      acl                  loophole
# for                  adposition                prep                 for
# rifles               noun                      pobj                 rifle
# with                 adposition                prep                 with
# a                    determiner                det                  a
# single               adjective                 amod                 single
# embrasure            noun                      pobj                 embrasure
# through              adposition                prep                 through
# which                determiner                pobj                 which
# protruded            verb                      relcl                protrude
# the                  determiner                det                  the
# muzzle               noun                      dobj                 muzzle
# of                   adposition                prep                 of
# a                    determiner                det                  a
# brass                noun                      compound             brass
# cannon               noun                      pobj                 cannon
# commanding           verb                      advcl                command
# the                  determiner                det                  the
# bridge               noun                      dobj                 bridge
# Midway               proper noun               nsubj                Midway
# up                   adposition                prt                  up
# the                  determiner                det                  the
# slope                noun                      dobj                 slope
# between              adposition                prep                 between
# the                  determiner                det                  the
# bridge               noun                      pobj                 bridge
# and                  coordinating conjunction  cc                   and
# fort                 noun                      conj                 fort
# were                 verb                      ROOT                 be
# the                  determiner                det                  the
# spectators           noun                      attr                 spectator
# a                    determiner                det                  a
# single               adjective                 amod                 single
# company              noun                      appos                company
# of                   adposition                prep                 of
# infantry             noun                      pobj                 infantry
# in                   adposition                prep                 in
# line                 noun                      pobj                 line
# at                   adposition                prep                 at
# parade               noun                      compound             parade
# rest                 noun                      pobj                 rest
# the                  determiner                det                  the
# butts                noun                      appos                butt
# of                   adposition                prep                 of
# their                determiner                poss                 -PRON-
# rifles               noun                      pobj                 rifle
# on                   adposition                prep                 on
# the                  determiner                det                  the
# ground               noun                      pobj                 ground
# the                  determiner                det                  the
# barrels              noun                      conj                 barrel
# inclining            verb                      acl                  incline
# slightly             adverb                    advmod               slightly
# backward             adjective                 advmod               backward
# against              adposition                prep                 against
# the                  determiner                det                  the
# right                adjective                 amod                 right
# shoulder             noun                      pobj                 shoulder
# the                  determiner                det                  the
# hands                noun                      nsubj                hand
# crossed              verb                      relcl                cross
# upon                 adposition                prep                 upon
# the                  determiner                det                  the
# stock                noun                      pobj                 stock
# A                    determiner                det                  a
# lieutenant           noun                      nsubj                lieutenant
# stood                verb                      ROOT                 stand
# at                   adposition                prep                 at
# the                  determiner                det                  the
# right                noun                      pobj                 right
# of                   adposition                prep                 of
# the                  determiner                det                  the
# line                 noun                      pobj                 line
# the                  determiner                det                  the
# point                noun                      npadvmod             point
# of                   adposition                prep                 of
# his                  determiner                poss                 -PRON-
# sword                noun                      pobj                 sword
# upon                 adposition                prep                 upon
# the                  determiner                det                  the
# ground               noun                      pobj                 ground
# his                  determiner                poss                 -PRON-
# left                 adjective                 amod                 left
# hand                 noun                      nsubj                hand
# resting              verb                      advcl                rest
# upon                 adposition                prep                 upon
# his                  determiner                poss                 -PRON-
# right                noun                      pobj                 right
# Excepting            verb                      advcl                except
# the                  determiner                det                  the
# group                noun                      dobj                 group
# of                   adposition                prep                 of
# four                 numeral                   pobj                 four
# at                   adposition                prep                 at
# the                  determiner                det                  the
# center               noun                      pobj                 center
# of                   adposition                prep                 of
# the                  determiner                det                  the
# bridge               noun                      pobj                 bridge
# not                  adverb                    neg                  not
# a                    determiner                det                  a
# man                  noun                      nsubj                man
# moved                verb                      ROOT                 move
# The                  determiner                det                  the
# company              noun                      nsubj                company
# faced                verb                      ROOT                 face
# the                  determiner                det                  the
# bridge               noun                      dobj                 bridge
# staring              verb                      advcl                stare
# stonily              adverb                    advmod               stonily
# motionless           adjective                 advmod               motionless
# The                  determiner                det                  the
# sentinels            noun                      nsubj                sentinel
# facing               verb                      acl                  face
# the                  determiner                det                  the
# banks                noun                      dobj                 bank
# of                   adposition                prep                 of
# the                  determiner                det                  the
# stream               noun                      pobj                 stream
# might                verb                      aux                  may
# have                 verb                      aux                  have
# been                 verb                      ROOT                 be
# statues              noun                      attr                 statue
# to                   particle                  aux                  to
# adorn                verb                      advcl                adorn
# the                  determiner                det                  the
# bridge               noun                      dobj                 bridge
# The                  determiner                det                  the
# captain              noun                      nsubj                captain
# stood                verb                      ROOT                 stand
# with                 adposition                prep                 with
# folded               verb                      amod                 fold
# arms                 noun                      pobj                 arm
# silent               adjective                 conj                 silent
# observing            verb                      advcl                observe
# the                  determiner                det                  the
# work                 noun                      dobj                 work
# of                   adposition                prep                 of
# his                  determiner                poss                 -PRON-
# subordinates         noun                      pobj                 subordinate
# but                  coordinating conjunction  cc                   but
# making               verb                      conj                 make
# no                   determiner                det                  no
# sign                 noun                      dobj                 sign
# Death                noun                      nsubj                death
# is                   verb                      ROOT                 be
# a                    determiner                det                  a
# dignitary            noun                      attr                 dignitary
# who                  pronoun                   nsubj                who
# when                 adverb                    advmod               when
# he                   pronoun                   nsubj                -PRON-
# comes                verb                      advcl                come
# announced            verb                      acomp                announce
# is                   verb                      relcl                be
# to                   particle                  aux                  to
# be                   verb                      auxpass              be
# received             verb                      xcomp                receive
# with                 adposition                prep                 with
# formal               adjective                 amod                 formal
# manifestations       noun                      pobj                 manifestation
# of                   adposition                prep                 of
# respect              noun                      pobj                 respect
# even                 adverb                    advmod               even
# by                   adposition                prep                 by
# those                determiner                pobj                 those
# most                 adverb                    advmod               most
# familiar             adjective                 amod                 familiar
# with                 adposition                prep                 with
# him                  pronoun                   pobj                 -PRON-
# In                   adposition                prep                 in
# the                  determiner                det                  the
# code                 noun                      nsubj                code
# of                   adposition                prep                 of
# military             adjective                 amod                 military
# etiquette            noun                      compound             etiquette
# silence              noun                      pobj                 silence
# and                  coordinating conjunction  cc                   and
# fixity               noun                      conj                 fixity
# are                  verb                      ROOT                 be
# forms                noun                      attr                 form
# of                   adposition                prep                 of
# deference            noun                      pobj                 deference
#
#
#                    space
#
#
# The                  determiner                det                  the
# man                  noun                      nsubj                man
# who                  pronoun                   nsubjpass            who
# was                  verb                      auxpass              be
# engaged              verb                      relcl                engage
# in                   adposition                prep                 in
# being                verb                      auxpass              be
# hanged               verb                      pcomp                hang
# was                  verb                      ROOT                 be
# apparently           adverb                    advmod               apparently
# about                adverb                    quantmod             about
# thirty               numeral                   compound             thirty
# -                    punctuation               punct                -
# five                 numeral                   nummod               five
# years                noun                      attr                 year
# of                   adposition                prep                 of
# age                  noun                      pobj                 age
# He                   pronoun                   nsubj                -PRON-
# was                  verb                      ROOT                 be
# a                    determiner                det                  a
# civilian             noun                      attr                 civilian
# if                   adposition                mark                 if
# one                  pronoun                   nsubj                one
# might                verb                      aux                  may
# judge                verb                      advcl                judge
# from                 adposition                prep                 from
# his                  determiner                poss                 -PRON-
# habit                noun                      dobj                 habit
# which                determiner                nsubj                which
# was                  verb                      relcl                be
# that                 determiner                attr                 that
# of                   adposition                prep                 of
# a                    determiner                det                  a
# planter              noun                      pobj                 planter
# His                  determiner                poss                 -PRON-
# features             noun                      nsubj                feature
# were                 verb                      ROOT                 be
# good                 adjective                 acomp                good
# a                    determiner                det                  a
# straight             adjective                 amod                 straight
# nose                 noun                      attr                 nose
# firm                 adjective                 amod                 firm
# mouth                noun                      conj                 mouth
# broad                adjective                 amod                 broad
# forehead             noun                      conj                 forehead
# from                 adposition                prep                 from
# which                determiner                pobj                 which
# his                  determiner                poss                 -PRON-
# long                 adjective                 amod                 long
# dark                 adjective                 amod                 dark
# hair                 noun                      nsubjpass            hair
# was                  verb                      auxpass              be
# combed               verb                      relcl                comb
# straight             adverb                    advmod               straight
# back                 adverb                    advmod               back
# falling              verb                      advcl                fall
# behind               adposition                prep                 behind
# his                  determiner                poss                 -PRON-
# ears                 noun                      pobj                 ear
# to                   adposition                prep                 to
# the                  determiner                det                  the
# collar               noun                      pobj                 collar
# of                   adposition                prep                 of
# his                  determiner                poss                 -PRON-
# well                 adverb                    advmod               well
# fitting              adjective                 amod                 fitting
# frock                noun                      compound             frock
# coat                 noun                      pobj                 coat
# He                   pronoun                   nsubj                -PRON-
# wore                 verb                      ccomp                wear
# a                    determiner                det                  a
# moustache            noun                      dobj                 moustache
# and                  coordinating conjunction  cc                   and
# pointed              verb                      conj                 point
# ...
# now                  adverb                    pcomp                now
# he                   pronoun                   nsubj                -PRON-
# sees                 verb                      ccomp                see
# another              determiner                det                  another
# scene                noun                      dobj                 scene
# perhaps              adverb                    advmod               perhaps
# he                   pronoun                   nsubj                -PRON-
# has                  verb                      aux                  have
# merely               adverb                    advmod               merely
# recovered            verb                      ROOT                 recover
# from                 adposition                prep                 from
# a                    determiner                det                  a
# delirium             noun                      pobj                 delirium
# He                   pronoun                   nsubj                -PRON-
# stands               verb                      ROOT                 stand
# at                   adposition                prep                 at
# the                  determiner                det                  the
# gate                 noun                      pobj                 gate
# of                   adposition                prep                 of
# his                  determiner                poss                 -PRON-
# own                  adjective                 amod                 own
# home                 noun                      pobj                 home
# All                  determiner                nsubj                all
# is                   verb                      ROOT                 be
# as                   adposition                mark                 as
# he                   pronoun                   nsubj                -PRON-
# left                 verb                      advcl                leave
# it                   pronoun                   dobj                 -PRON-
# and                  coordinating conjunction  cc                   and
# all                  determiner                advmod               all
# bright               adjective                 conj                 bright
# and                  coordinating conjunction  cc                   and
# beautiful            adjective                 conj                 beautiful
# in                   adposition                prep                 in
# the                  determiner                det                  the
# morning              noun                      compound             morning
# sunshine             noun                      pobj                 sunshine
# He                   pronoun                   nsubj                -PRON-
# must                 verb                      aux                  must
# have                 verb                      aux                  have
# traveled             verb                      ROOT                 travel
# the                  determiner                det                  the
# entire               adjective                 amod                 entire
# night                noun                      dobj                 night
# As                   adposition                mark                 as
# he                   pronoun                   nsubj                -PRON-
# pushes               verb                      advcl                push
# open                 adjective                 advmod               open
# the                  determiner                det                  the
# gate                 noun                      dobj                 gate
# and                  coordinating conjunction  cc                   and
# passes               verb                      conj                 pass
# up                   adposition                prep                 up
# the                  determiner                det                  the
# wide                 adjective                 amod                 wide
# white                adjective                 amod                 white
# walk                 noun                      pobj                 walk
# he                   pronoun                   nsubj                -PRON-
# sees                 verb                      ccomp                see
# a                    determiner                det                  a
# flutter              noun                      dobj                 flutter
# of                   adposition                prep                 of
# female               adjective                 amod                 female
# garments             noun                      pobj                 garment
# his                  determiner                poss                 -PRON-
# wife                 noun                      nsubj                wife
# looking              verb                      acl                  look
# fresh                adjective                 advmod               fresh
# and                  coordinating conjunction  cc                   and
# cool                 adjective                 conj                 cool
# and                  coordinating conjunction  cc                   and
# sweet                adjective                 conj                 sweet
# steps                verb                      ROOT                 step
# down                 particle                  prt                  down
# from                 adposition                prep                 from
# the                  determiner                det                  the
# veranda              noun                      pobj                 veranda
# to                   particle                  prep                 to
# meet                 verb                      advcl                meet
# him                  pronoun                   dobj                 -PRON-
# At                   adposition                ROOT                 at
# the                  determiner                det                  the
# bottom               noun                      pobj                 bottom
# of                   adposition                prep                 of
# the                  determiner                det                  the
# steps                noun                      pobj                 step
# she                  pronoun                   nsubj                -PRON-
# stands               verb                      relcl                stand
# waiting              verb                      xcomp                wait
# with                 adposition                prep                 with
# a                    determiner                det                  a
# smile                noun                      pobj                 smile
# of                   adposition                prep                 of
# ineffable            adjective                 amod                 ineffable
# joy                  noun                      pobj                 joy
# an                   determiner                det                  an
# attitude             noun                      pobj                 attitude
# of                   adposition                prep                 of
# matchless            adjective                 compound             matchless
# grace                noun                      pobj                 grace
# and                  coordinating conjunction  cc                   and
# dignity              noun                      conj                 dignity
# Ah                   interjection              intj                 ah
# how                  adverb                    advmod               how
# beautiful            adjective                 attr                 beautiful
# she                  pronoun                   nsubj                -PRON-
# is                   verb                      ROOT                 be
# He                   pronoun                   nsubj                -PRON-
# springs              verb                      ROOT                 spring
# forwards             noun                      dobj                 forward
# with                 adposition                prep                 with
# extended             adjective                 amod                 extended
# arms                 noun                      pobj                 arm
# As                   adposition                mark                 as
# he                   pronoun                   nsubj                -PRON-
# is                   verb                      advcl                be
# about                adposition                prep                 about
# to                   particle                  aux                  to
# clasp                verb                      xcomp                clasp
# her                  pronoun                   dobj                 -PRON-
# he                   pronoun                   nsubj                -PRON-
# feels                verb                      ccomp                feel
# a                    determiner                det                  a
# stunning             adjective                 amod                 stunning
# blow                 noun                      dobj                 blow
# upon                 adposition                prep                 upon
# the                  determiner                det                  the
# back                 noun                      pobj                 back
# of                   adposition                prep                 of
# the                  determiner                det                  the
# neck                 noun                      pobj                 neck
# a                    determiner                det                  a
# blinding             verb                      amod                 blind
# white                adjective                 amod                 white
# light                adjective                 nsubj                light
# blazes               noun                      ccomp                blaze
# all                  adverb                    advmod               all
# about                adposition                prep                 about
# him                  pronoun                   pobj                 -PRON-
# with                 adposition                prep                 with
# a                    determiner                det                  a
# sound                noun                      pobj                 sound
# like                 adposition                prep                 like
# the                  determiner                det                  the
# shock                noun                      pobj                 shock
# of                   adposition                prep                 of
# a                    determiner                det                  a
# cannon               noun                      pobj                 cannon
# then                 adverb                    advmod               then
# all                  determiner                nsubj                all
# is                   verb                      ROOT                 be
# darkness             noun                      attr                 darkness
# and                  coordinating conjunction  cc                   and
# silence              noun                      conj                 silence
#
#
#                    space
#
#
# Peyton               proper noun               compound             Peyton
# Farquhar             proper noun               nsubj                Farquhar
# was                  verb                      ccomp                be
# dead                 adjective                 acomp                dead
# his                  determiner                poss                 -PRON-
# body                 noun                      nsubj                body
# with                 adposition                prep                 with
# a                    determiner                det                  a
# broken               verb                      amod                 break
# neck                 noun                      pobj                 neck
# swung                verb                      ROOT                 swing
# gently               adverb                    advmod               gently
# from                 adposition                prep                 from
# side                 noun                      pobj                 side
# to                   adposition                aux                  to
# side                 noun                      advcl                side
# beneath              adposition                prep                 beneath
# the                  determiner                det                  the
# timbers              noun                      pobj                 timber
# of                   adposition                prep                 of
# the                  determiner                det                  the
# Owl                  proper noun               compound             Owl
# Creek                proper noun               compound             Creek
# bridge               noun                      pobj                 bridge
#
#
#                    space

# %% [markdown]
# **6. Write a matcher called 'Swimming' that finds both occurrences of the phrase "swimming vigorously" in the text**<br>
# HINT: You should include an `'IS_SPACE': True` pattern between the two words!

# %%
# Import the Matcher library:

from spacy.matcher import Matcher
matcher = Matcher(nlp.vocab)

# %%
# Create a pattern and add it to matcher:
pattern1 = [{'Lower':'swimming'},{'IS_SPACE':True},{'Lower':'vigorously'}]
#pattern1 = [{'Lower':'swimming'},{'IS_SPACE':True, 'OP' : '*'},{'Lower':'vigorously'}]
matcher.add('swimming',None,pattern1)

# %%
# Create a list of matches called "found_matches" and print the list:
found_matches = matcher(doc)
found_matches
# Out:
# [(12526975369366237900, 1274, 1277), (12526975369366237900, 3607, 3610)]

# %%
for match_id, start, end in found_matches:
  string_id = nlp.vocab.strings[match_id]
  span = doc[start:end]
  print(match_id,string_id,start,end,span.text)
# Out:
# 12526975369366237900 swimming 1274 1277 swimming
# vigorously
# 12526975369366237900 swimming 3607 3610 swimming
# vigorously

# %% [markdown]
# **7. Print the text surrounding each found match**

# %%
#1274 to 1277
doc[1260:1290]
# Out:
# into the stream.  By diving I could evade the bullets and, swimming
# vigorously, reach the bank, take to the woods and get away home

# %%
#3607 to 3610
doc[3600:3620]
# Out:
# over his shoulder; he was now swimming
# vigorously with the current.  His brain was as energetic

# %% [markdown]
# **EXTRA CREDIT:<br>Print the *sentence* that contains each found match**

# %%
found_matches
# Out:
# [(12526975369366237900, 1274, 1277), (12526975369366237900, 3607, 3610)]

# %%
for sent in sents:
  if found_matches[0][1] < sent.end:
    print(sent)
    break
# Out:
# By diving I could evade the bullets and, swimming
# vigorously, reach the bank, take to the woods and get away home.

# %%
for sent in sents:
  if found_matches[1][1] < sent.end:
    print(sent)
    break
# Out:
# The hunted man saw all this over his shoulder; he was now swimming
# vigorously with the current.
